# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
import statsmodels.api as sm

# %%
data_dir = os.getcwd() + '/data'

modeling_df = pd.read_csv("{}/cleaned_modeling_data.csv".format(data_dir))

pred_df = modeling_df.drop(["num_testtakers", "num_offered", "pct_8th_graders_offered"], axis=1)
response_df = modeling_df["num_testtakers"].fillna(0)

pred_train, pred_test, response_train, response_test = train_test_split(pred_df, response_df, test_size=0.2, random_state=223)

# %%
# col_name = "Economic Need Index"
# print(modeling_df[col_name].describe())
# print(modeling_df[col_name].notnull().sum())
# print(modeling_df[col_name].isnull().sum())

# x_train = pred_train[col_name].to_frame().values
# x_test = pred_test[col_name].to_frame().values

# plt.xlabel(col_name)
# plt.ylabel("# Testtakers - 2017")
# plt.scatter(x_train, response_train, alpha = 0.5)
# plt.show()

# pred_regr = linear_model.LinearRegression()
# pred_model = pred_regr.fit(x_train, response_train)

# y_pred = regr.predict(x_test)
# # The coefficients
# print('Coefficients: \n', pred_regr.coef_)
# # The mean squared error
# print("Mean squared error: %.2f"
#       % mean_squared_error(response_test, y_pred))
# # Explained variance score: 1 is perfect prediction
# print('Variance score: %.2f' % r2_score(response_test, y_pred))

#print(school_explorer_df[col_name].astype(column_cast_obj[col_name]).describe())
col_name = "incoming_ela_level_4_2016_n"
print(pred_train[col_name].isnull().sum())
# Out:
# 156

# %%
sm_x_train = pred_train[col_name]
sm_x_train = sm.add_constant(sm_x_train)

sm_model = sm.OLS(response_train, sm_x_train, missing='drop')
sm_results = sm_model.fit()

print(sm_results.summary())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-a0e487871b57> in <module>()
#       2 sm_x_train = sm.add_constant(sm_x_train)
#       3
# ----> 4 sm_model = sm.OLS(response_train, sm_x_train, missing='drop')
#       5 sm_results = sm_model.fit()
#       6
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#     815                  **kwargs):
#     816         super(OLS, self).__init__(endog, exog, missing=missing,
# --> 817                                   hasconst=hasconst, **kwargs)
#     818         if "weights" in self._init_keys:
#     819             self._init_keys.remove("weights")
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, weights, missing, hasconst, **kwargs)
#     661             weights = weights.squeeze()
#     662         super(WLS, self).__init__(endog, exog, missing=missing,
# --> 663                                   weights=weights, hasconst=hasconst, **kwargs)
#     664         nobs = self.exog.shape[0]
#     665         weights = self.weights
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/regression/linear_model.py in __init__(self, endog, exog, **kwargs)
#     177     """
#     178     def __init__(self, endog, exog, **kwargs):
# --> 179         super(RegressionModel, self).__init__(endog, exog, **kwargs)
#     180         self._data_attr.extend(['pinv_wexog', 'wendog', 'wexog', 'weights'])
#     181
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     210
#     211     def __init__(self, endog, exog=None, **kwargs):
# --> 212         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     213         self.initialize()
#     214
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      62         hasconst = kwargs.pop('hasconst', None)
#      63         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 64                                       **kwargs)
#      65         self.k_constant = self.data.k_constant
#      66         self.exog = self.data.exog
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      85
#      86     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# ---> 87         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#      88         # kwargs arrays could have changed, easier to just attach here
#      89         for key in kwargs:
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     631     klass = handle_data_class_factory(endog, exog)
#     632     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 633                  **kwargs)
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      69             self.orig_exog = self.exog
#      70             self.endog, self.exog = self._convert_endog_exog(self.endog,
# ---> 71                                                              self.exog)
#      72         else:
#      73             self.__dict__.update(kwargs)  # attach the extra arrays anyway
#
# ~/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/site-packages/statsmodels/base/data.py in _convert_endog_exog(self, endog, exog)
#     472         exog = exog if exog is None else np.asarray(exog)
#     473         if endog.dtype == object or exog is not None and exog.dtype == object:
# --> 474             raise ValueError("Pandas data cast to numpy dtype of object. "
#     475                              "Check input data with np.asarray(data).")
#     476         return super(PandasData, self)._convert_endog_exog(endog, exog)
#
# ValueError: Pandas data cast to numpy dtype of object. Check input data with np.asarray(data).

# %%
nobs = float(len(modeling_df))

for col_name in modeling_df.columns.values:
    
    col_nulls = float(modeling_df[col_name].isnull().sum())
    perc_nulls = col_nulls / nobs
    
    if perc_nulls > 0:

        print("{} : {}".format(col_name, modeling_df[col_name].isnull().sum()))
# Out:
# num_testtakers : 21
# num_offered : 21
# pct_8th_graders_offered : 21
# pct_black_hispanic : 21
# Rigorous Instruction Rating : 16
# Collaborative Teachers Rating : 16
# Supportive Environment Rating : 21
# Effective School Leadership Rating : 14
# Strong Family-Community Ties Rating : 16
# Trust Rating : 16
# Student Achievement Rating : 11
# asian_pacific_2016_num_students : 185
# asian_pacific_2017_num_students : 165
# avg_math_proficiency_2017 : 2
# avg_math_proficiency_2017_city_diff : 2
# avg_math_proficiency_2017_comp_diff : 2
# black_2016_avg_ela : 61
# black_2016_avg_math : 66
# black_2016_incoming_ela : 225
# black_2016_incoming_math : 222
# black_2016_num_students : 14
# black_2017_avg_ela : 60
# black_2017_avg_math : 64
# black_2017_incoming_ela : 224
# black_2017_incoming_math : 225
# black_2017_num_students : 11
# grade_7_2015_enrollment : 21
# grade_7_2017_enrollment : 1
# grade_8_2015_enrollment : 51
# grade_8_2016_enrollment : 22
# hispanic_2016_avg_ela : 27
# hispanic_2016_avg_math : 28
# hispanic_2016_incoming_ela : 205
# hispanic_2016_incoming_math : 204
# hispanic_2016_num_students : 4
# hispanic_2017_avg_ela : 25
# hispanic_2017_avg_math : 26
# hispanic_2017_incoming_ela : 209
# hispanic_2017_incoming_math : 208
# hispanic_2017_num_students : 2
# incoming_avg_5th_grade_ela_rating_2016_city_diff : 182
# incoming_avg_5th_grade_ela_rating_2016_dist_diff : 182
# incoming_avg_5th_grade_ela_rating_2016_val : 182
# incoming_avg_5th_grade_ela_rating_2017_city_diff : 189
# incoming_avg_5th_grade_ela_rating_2017_dist_diff : 189
# incoming_avg_5th_grade_ela_rating_2017_val : 189
# incoming_avg_5th_grade_math_rating_2016_city_diff : 182
# incoming_avg_5th_grade_math_rating_2016_dist_diff : 182
# incoming_avg_5th_grade_math_rating_2016_val : 182
# incoming_avg_5th_grade_math_rating_2017_city_diff : 189
# incoming_avg_5th_grade_math_rating_2017_dist_diff : 189
# incoming_avg_5th_grade_math_rating_2017_val : 189
# incoming_ela_level_1_2016_city_diff : 196
# incoming_ela_level_1_2016_dist_diff : 196
# incoming_ela_level_1_2016_n : 184
# incoming_ela_level_1_2016_val : 187
# incoming_ela_level_1_2017_city_diff : 195
# incoming_ela_level_1_2017_dist_diff : 195
# incoming_ela_level_1_2017_n : 191
# incoming_ela_level_1_2017_val : 195
# incoming_ela_level_2_2016_city_diff : 195
# incoming_ela_level_2_2016_dist_diff : 195
# incoming_ela_level_2_2016_n : 183
# incoming_ela_level_2_2016_val : 185
# incoming_ela_level_2_2017_city_diff : 192
# incoming_ela_level_2_2017_dist_diff : 192
# incoming_ela_level_2_2017_n : 191
# incoming_ela_level_2_2017_val : 192
# incoming_ela_level_3_2016_city_diff : 196
# incoming_ela_level_3_2016_dist_diff : 196
# incoming_ela_level_3_2016_n : 185
# incoming_ela_level_3_2016_val : 186
# incoming_ela_level_3_2017_city_diff : 197
# incoming_ela_level_3_2017_dist_diff : 197
# incoming_ela_level_3_2017_n : 191
# incoming_ela_level_3_2017_val : 197
# incoming_ela_level_4_2016_city_diff : 281
# incoming_ela_level_4_2016_dist_diff : 281
# incoming_ela_level_4_2016_n : 195
# incoming_ela_level_4_2016_val : 280
# incoming_ela_level_4_2017_city_diff : 250
# incoming_ela_level_4_2017_dist_diff : 250
# incoming_ela_level_4_2017_n : 194
# incoming_ela_level_4_2017_val : 250
# incoming_math_level_1_2016_city_diff : 196
# incoming_math_level_1_2016_dist_diff : 196
# incoming_math_level_1_2016_n : 184
# incoming_math_level_1_2016_val : 187
# incoming_math_level_1_2017_city_diff : 193
# incoming_math_level_1_2017_dist_diff : 193
# incoming_math_level_1_2017_n : 190
# incoming_math_level_1_2017_val : 193
# incoming_math_level_2_2016_city_diff : 194
# incoming_math_level_2_2016_dist_diff : 194
# incoming_math_level_2_2016_n : 184
# incoming_math_level_2_2016_val : 185
# incoming_math_level_2_2017_city_diff : 192
# incoming_math_level_2_2017_dist_diff : 192
# incoming_math_level_2_2017_n : 189
# incoming_math_level_2_2017_val : 192
# incoming_math_level_3_2016_city_diff : 198
# incoming_math_level_3_2016_dist_diff : 198
# incoming_math_level_3_2016_n : 184
# incoming_math_level_3_2016_val : 188
# incoming_math_level_3_2017_city_diff : 194
# incoming_math_level_3_2017_dist_diff : 194
# incoming_math_level_3_2017_n : 189
# incoming_math_level_3_2017_val : 194
# incoming_math_level_4_2016_city_diff : 257
# incoming_math_level_4_2016_dist_diff : 257
# incoming_math_level_4_2016_n : 192
# incoming_math_level_4_2016_val : 251
# incoming_math_level_4_2017_city_diff : 256
# incoming_math_level_4_2017_dist_diff : 256
# incoming_math_level_4_2017_n : 197
# incoming_math_level_4_2017_val : 256
# pct_8th_graders_w_hs_credit_2016 : 25
# pct_8th_graders_w_hs_credit_2016_city_diff : 25
# pct_8th_graders_w_hs_credit_2016_comp_diff : 25
# pct_8th_graders_w_hs_credit_2017 : 5
# pct_8th_graders_w_hs_credit_2017_city_diff : 5
# pct_8th_graders_w_hs_credit_2017_comp_diff : 5
# pct_ell_2016_city_diff : 60
# pct_ell_2016_dist_diff : 60
# pct_ell_2016_val : 60
# pct_ell_2017_city_diff : 59
# pct_ell_2017_dist_diff : 59
# pct_ell_2017_val : 59
# pct_math_level_3_or_4_2017 : 2
# pct_math_level_3_or_4_2017_city_diff : 2
# pct_math_level_3_or_4_2017_comp_diff : 2
# pct_students_w_disabilities_2016_city_diff : 6
# pct_students_w_disabilities_2016_dist_diff : 6
# pct_students_w_disabilities_2016_val : 6
# pct_students_w_disabilities_2017_city_diff : 5
# pct_students_w_disabilities_2017_dist_diff : 5
# pct_students_w_disabilities_2017_val : 5
# pct_temp_housing_2016_city_diff : 13
# pct_temp_housing_2016_dist_diff : 13
# pct_temp_housing_2016_val : 13
# pct_temp_housing_2017_city_diff : 9
# pct_temp_housing_2017_dist_diff : 9
# pct_temp_housing_2017_val : 9
# sa_attendance_90plus_2016 : 10
# sa_attendance_90plus_2016_city_diff : 10
# sa_attendance_90plus_2016_dist_diff : 10
# sa_attendance_90plus_2017 : 5
# sa_attendance_90plus_2017_city_diff : 5
# sa_attendance_90plus_2017_dist_diff : 5
# white_2016_num_students : 196
# white_2017_num_students : 184

# %%
cols_w_5_nans = ["avg_math_proficiency_2017", "pct_8th_graders_w_hs_credit_2017", "pct_math_level_3_or_4_2017", "pct_students_w_disabilities_2017_val", "pct_temp_housing_2017_val", "sa_attendance_90plus_2017"]
for idx, row in cleaned_modeling_df.iterrows():
    if np.isnan(row["sa_attendance_90plus_2017"]):
        print("--------------")
        print(idx)
        print("{} / {}".format(row["school_name"], row['dbn']))
        
        for col in cols_w_5_nans:
            print("{} : {}".format(col, row[col]))
# Out:
# --------------
# 115
# SUCCESS ACADEMY CHARTER SCHOOL - BRONX 2 / 84X494
# avg_math_proficiency_2017 : 3.93
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.934
# pct_students_w_disabilities_2017_val : 0.142
# pct_temp_housing_2017_val : 0.094
# sa_attendance_90plus_2017 : nan
# --------------
# 379
# SUCCESS ACADEMY CHARTER SCHOOL - HARLEM 4 / 84M386
# avg_math_proficiency_2017 : 3.85
# pct_8th_graders_w_hs_credit_2017 : 0.0
# pct_math_level_3_or_4_2017 : 0.89
# pct_students_w_disabilities_2017_val : 0.226
# pct_temp_housing_2017_val : 0.126
# sa_attendance_90plus_2017 : nan
# --------------
# 471
# SUCCESS ACADEMY CHARTER SCHOOL - HARLEM 3 / 84M385
# avg_math_proficiency_2017 : 3.82
# pct_8th_graders_w_hs_credit_2017 : 0.0
# pct_math_level_3_or_4_2017 : 0.909
# pct_students_w_disabilities_2017_val : 0.16399999999999998
# pct_temp_housing_2017_val : 0.103
# sa_attendance_90plus_2017 : nan
# --------------
# 479
# SUCCESS ACADEMY CHARTER SCHOOL - BRONX 1 / 84X493
# avg_math_proficiency_2017 : 3.97
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.964
# pct_students_w_disabilities_2017_val : 0.14400000000000002
# pct_temp_housing_2017_val : 0.079
# sa_attendance_90plus_2017 : nan
# --------------
# 515
# SUCCESS ACADEMY CHARTER SCHOOL - HARLEM 2 / 84M384
# avg_math_proficiency_2017 : 3.88
# pct_8th_graders_w_hs_credit_2017 : 0.0
# pct_math_level_3_or_4_2017 : 0.938
# pct_students_w_disabilities_2017_val : 0.192
# pct_temp_housing_2017_val : 0.114
# sa_attendance_90plus_2017 : nan
# --------------
# 526
# BROOKLYN LAB?CHARTER SCHOOL / 84K803
# avg_math_proficiency_2017 : 2.46
# pct_8th_graders_w_hs_credit_2017 : 0.0
# pct_math_level_3_or_4_2017 : 0.24
# pct_students_w_disabilities_2017_val : 0.284
# pct_temp_housing_2017_val : 0.127
# sa_attendance_90plus_2017 : nan
# --------------
# 527
# SUCCESS ACADEMY CHARTER SCHOOL - HARLEM 5 / 84M482
# avg_math_proficiency_2017 : 3.84
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.919
# pct_students_w_disabilities_2017_val : 0.211
# pct_temp_housing_2017_val : 0.108
# sa_attendance_90plus_2017 : nan
# --------------
# 546
# ATMOSPHERE CHARTER SCHOOL / 84X460
# avg_math_proficiency_2017 : 2.31
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.182
# pct_students_w_disabilities_2017_val : 0.257
# pct_temp_housing_2017_val : 0.213
# sa_attendance_90plus_2017 : nan
# --------------
# 563
# BROOKLYN EAST COLLEGIATE CHARTER SCHOOL / 84K780
# avg_math_proficiency_2017 : 2.87
# pct_8th_graders_w_hs_credit_2017 : 0.8190000000000001
# pct_math_level_3_or_4_2017 : 0.434
# pct_students_w_disabilities_2017_val : 0.165
# pct_temp_housing_2017_val : 0.09
# sa_attendance_90plus_2017 : nan
# --------------
# 598
# ORCHARD COLLEGIATE ACADEMY / 01M292
# avg_math_proficiency_2017 : nan
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : nan
# pct_students_w_disabilities_2017_val : nan
# pct_temp_housing_2017_val : nan
# sa_attendance_90plus_2017 : nan
# --------------
# 746
# NEW DIRECTIONS SECONDARY SCHOOL / 09X350
# avg_math_proficiency_2017 : nan
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : nan
# pct_students_w_disabilities_2017_val : nan
# pct_temp_housing_2017_val : nan
# sa_attendance_90plus_2017 : nan
# --------------
# 1228
# SUCCESS ACADEMY CHARTER SCHOOL - BED-STUY 2 / 84K125
# avg_math_proficiency_2017 : 4.07
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.975
# pct_students_w_disabilities_2017_val : 0.18600000000000005
# pct_temp_housing_2017_val : 0.126
# sa_attendance_90plus_2017 : nan
# --------------
# 1229
# SUCCESS ACADEMY CHARTER SCHOOL - COBBLE HILL / 84K129
# avg_math_proficiency_2017 : 4.02
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.96
# pct_students_w_disabilities_2017_val : 0.118
# pct_temp_housing_2017_val : 0.077
# sa_attendance_90plus_2017 : nan
# --------------
# 1230
# SUCCESS ACADEMY CHARTER SCHOOL - WILLIAMSBURG / 84K182
# avg_math_proficiency_2017 : 3.94
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.927
# pct_students_w_disabilities_2017_val : 0.166
# pct_temp_housing_2017_val : 0.08199999999999999
# sa_attendance_90plus_2017 : nan
# --------------
# 1231
# SUCCESS ACADEMY CHARTER SCHOOL - BED-STUY 1 / 84K367
# avg_math_proficiency_2017 : 4.16
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.984
# pct_students_w_disabilities_2017_val : 0.161
# pct_temp_housing_2017_val : 0.132
# sa_attendance_90plus_2017 : nan
# --------------
# 1238
# BEGINNING WITH CHILDREN CHARTER SCHOOL / 84K703
# avg_math_proficiency_2017 : nan
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : nan
# pct_students_w_disabilities_2017_val : nan
# pct_temp_housing_2017_val : nan
# sa_attendance_90plus_2017 : nan
# --------------
# 1257
# NEW YORK FRENCH AMERICAN CHARTER SCHOOL / 84M483
# avg_math_proficiency_2017 : nan
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : nan
# pct_students_w_disabilities_2017_val : nan
# pct_temp_housing_2017_val : nan
# sa_attendance_90plus_2017 : nan
# --------------
# 1259
# SUCCESS ACADEMY CHARTER SCHOOL - UPPER WEST / 84M523
# avg_math_proficiency_2017 : 4.09
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.96
# pct_students_w_disabilities_2017_val : 0.185
# pct_temp_housing_2017_val : 0.08
# sa_attendance_90plus_2017 : nan
# --------------
# 1266
# STATEN ISLAND COMMUNITY CHARTER SCHOOL / 84R071
# avg_math_proficiency_2017 : nan
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : nan
# pct_students_w_disabilities_2017_val : nan
# pct_temp_housing_2017_val : nan
# sa_attendance_90plus_2017 : nan
# --------------
# 1267
# CHILDREN'S AID COLLEGE PREP CHARTER SCHOOL / 84X124
# avg_math_proficiency_2017 : 3.21
# pct_8th_graders_w_hs_credit_2017 : nan
# pct_math_level_3_or_4_2017 : 0.612
# pct_students_w_disabilities_2017_val : 0.198
# pct_temp_housing_2017_val : 0.121
# sa_attendance_90plus_2017 : nan

# %%
#pred_train[col_name].to_frame().isnull().sum()
cleaned_modeling_df.columns.values
# Out:
# array(['school_name', 'dbn', 'num_testtakers', 'num_offered',
#        'pct_8th_graders_offered', 'pct_black_hispanic', 'SED Code',
#        'District', 'Latitude', 'Longitude', 'Address (Full)', 'City',
#        'Zip', 'Grades', 'Grade Low', 'Grade High', 'Community School?',
#        'Economic Need Index', 'Percent ELL', 'Percent Asian',
#        'Percent Black', 'Percent Hispanic', 'Percent Black / Hispanic',
#        'Percent White', 'Student Attendance Rate',
#        'Percent of Students Chronically Absent', 'Rigorous Instruction %',
#        'Rigorous Instruction Rating', 'Collaborative Teachers %',
#        'Collaborative Teachers Rating', 'Supportive Environment %',
#        'Supportive Environment Rating', 'Effective School Leadership %',
#        'Effective School Leadership Rating',
#        'Strong Family-Community Ties %',
#        'Strong Family-Community Ties Rating', 'Trust %', 'Trust Rating',
#        'Student Achievement Rating', 'Average ELA Proficiency',
#        'Average Math Proficiency', 'asian_pacific_2017_num_students',
#        'avg_math_proficiency_2016', 'avg_math_proficiency_2016_city_diff',
#        'avg_math_proficiency_2016_comp_diff', 'avg_math_proficiency_2017',
#        'avg_math_proficiency_2017_city_diff',
#        'avg_math_proficiency_2017_comp_diff', 'black_2016_avg_ela',
#        'black_2016_avg_math', 'black_2016_num_students',
#        'black_2017_avg_ela', 'black_2017_avg_math',
#        'black_2017_num_students', 'econ_need_index_2016_city_diff',
#        'econ_need_index_2016_dist_diff', 'econ_need_index_2016_val',
#        'econ_need_index_2017_city_diff', 'econ_need_index_2017_dist_diff',
#        'econ_need_index_2017_val', 'grade_7_2015_enrollment',
#        'grade_7_2016_enrollment', 'grade_7_2017_enrollment',
#        'grade_8_2015_enrollment', 'grade_8_2016_enrollment',
#        'grade_8_2017_enrollment', 'hispanic_2016_avg_ela',
#        'hispanic_2016_avg_math', 'hispanic_2016_num_students',
#        'hispanic_2017_avg_ela', 'hispanic_2017_avg_math',
#        'hispanic_2017_num_students', 'pct_8th_graders_w_hs_credit_2016',
#        'pct_8th_graders_w_hs_credit_2016_city_diff',
#        'pct_8th_graders_w_hs_credit_2016_comp_diff',
#        'pct_8th_graders_w_hs_credit_2017',
#        'pct_8th_graders_w_hs_credit_2017_city_diff',
#        'pct_8th_graders_w_hs_credit_2017_comp_diff',
#        'pct_ell_2016_city_diff', 'pct_ell_2016_dist_diff',
#        'pct_ell_2016_val', 'pct_ell_2017_city_diff',
#        'pct_ell_2017_dist_diff', 'pct_ell_2017_val',
#        'pct_hra_assistance_2016_city_diff',
#        'pct_hra_assistance_2016_dist_diff', 'pct_hra_assistance_2016_val',
#        'pct_hra_assistance_2017_city_diff',
#        'pct_hra_assistance_2017_dist_diff', 'pct_hra_assistance_2017_val',
#        'pct_math_level_3_or_4_2016',
#        'pct_math_level_3_or_4_2016_city_diff',
#        'pct_math_level_3_or_4_2016_comp_diff',
#        'pct_math_level_3_or_4_2017',
#        'pct_math_level_3_or_4_2017_city_diff',
#        'pct_math_level_3_or_4_2017_comp_diff',
#        'pct_poverty_2016_city_diff', 'pct_poverty_2016_dist_diff',
#        'pct_poverty_2016_val', 'pct_poverty_2017_city_diff',
#        'pct_poverty_2017_dist_diff', 'pct_poverty_2017_val',
#        'pct_students_w_disabilities_2016_city_diff',
#        'pct_students_w_disabilities_2016_dist_diff',
#        'pct_students_w_disabilities_2016_val',
#        'pct_students_w_disabilities_2017_city_diff',
#        'pct_students_w_disabilities_2017_dist_diff',
#        'pct_students_w_disabilities_2017_val',
#        'pct_temp_housing_2016_city_diff',
#        'pct_temp_housing_2016_dist_diff', 'pct_temp_housing_2016_val',
#        'pct_temp_housing_2017_city_diff',
#        'pct_temp_housing_2017_dist_diff', 'pct_temp_housing_2017_val',
#        'sa_attendance_90plus_2016', 'sa_attendance_90plus_2016_city_diff',
#        'sa_attendance_90plus_2016_dist_diff', 'sa_attendance_90plus_2017',
#        'sa_attendance_90plus_2017_city_diff',
#        'sa_attendance_90plus_2017_dist_diff', 'grade_8_flg'], dtype=object)

# %%
print(len(cleaned_modeling_df[~cleaned_modeling_df['dbn'].isin(["15K839", "03M291", "84X492", "84X460", "28Q358"])]))
# Out:
# 591

# %%
print(len(cleaned_modeling_df))
# Out:
# 596
