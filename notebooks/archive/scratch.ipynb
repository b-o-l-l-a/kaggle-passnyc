# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model, metrics, preprocessing
import statsmodels.api as sm
from statsmodels.regression.linear_model import RegressionResults
import geopy.distance
# Out:
# /Users/greg.bolla/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/greg.bolla/.local/share/virtualenvs/kaggle-passnyc-hqRn-hsS/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
cwd = os.getcwd()
input_data_dir =  cwd.replace('/notebooks/archive', '') + '/data/interim'
output_data_dir = cwd.replace('/notebooks/archive', '') + '/data/processed'
output_model_summaries_dir =  cwd.replace('/notebooks/archive', '') + '/models'

interim_modeling_df = pd.read_csv("{}/step3_interim_modeling_data.csv".format(input_data_dir))

invalid_preds = ["school_name", "dbn", "Address (Full)", "City", "Grades", "Grade Low", "Grade High", \
"SED Code", "Latitude", "Longitude", "Zip"]
response_vars = ["num_testtakers", "num_offered", "pct_8th_graders_offered", "perc_testtakers", "perc_testtakers_quartile"]
response_var = "perc_testtakers"

# incl dbn and school_name for convenience and to id each row
response_df_cols = ["dbn", "school_name", response_var]

response_df = interim_modeling_df[response_df_cols]
pred_df = interim_modeling_df.drop(response_df_cols, axis=1)

pred_train, pred_test, response_train, response_test = train_test_split(pred_df, response_df, test_size=0.2, random_state=223)

# %%
def adj_r2_score(lm, y, y_pred):
    adj_r2 = 1 - float(len(y)-1)/(len(y)-len(lm.coef_)-1)*(1 - metrics.r2_score(y,y_pred))
    return adj_r2

# %%
col_list = pred_train.columns.values
col_name = "Average ELA Proficiency"
#print(pred_train[col_name].describe())
# print(modeling_df[col_name].notnull().sum())
# print(modeling_df[col_name].isnull().sum())

x_train_df = pred_train[[col_name]]
x_test_df = pred_test[[col_name]]
x_model = linear_model.LinearRegression()
x_results = x_model.fit(x_train_df, response_train[response_var])

y_predicted_test = x_results.predict(x_test_df)
med_absolute_error = metrics.median_absolute_error(response_test[response_var], y_predicted_test)
r2 = metrics.r2_score(response_test[response_var],y_predicted_test)
adj_r2 = adj_r2_score(x_results, response_test[response_var],y_predicted_test)

coef_dict = {}
model_rows = []
for idx, col in enumerate(x_train_df.columns.values):
    coef_dict[col] = x_results.coef_[idx]
    model_row = {}
    model_row['model'] = col_name
    pred_coef = x_results.coef_[idx]
    model_row['model_r2'] = r2
    model_row['model_adj_r2'] = adj_r2
    model_row['median_absolute_error'] = med_absolute_error
    model_row['pred_col'] = col
    model_row['pred_coef'] = pred_coef
    model_rows.append(model_row)
    
print(model_rows)
#x_train = pred_train[col_name].to_frame().values
#x_test = pred_test[col_name].to_frame().values

# plt.xlabel(col_name)
# plt.ylabel("# Testtakers - 2017")
# plt.scatter(x_train, response_train, alpha = 0.5)
# plt.show()

# pred_regr = linear_model.LinearRegression()
# pred_model = pred_regr.fit(x_train, response_train)

# y_pred = regr.predict(x_test)
# # The coefficients
# print('Coefficients: \n', pred_regr.coef_)
# # The mean squared error
# print("Mean squared error: %.2f"
#       % mean_squared_error(response_test, y_pred))
# # Explained variance score: 1 is perfect prediction
# print('Variance score: %.2f' % r2_score(response_test, y_pred))
# Out:
# [{'model': 'Average ELA Proficiency', 'model_r2': 0.49273353344970594, 'model_adj_r2': 0.4881635652825862, 'median_absolute_error': 0.10271622745356435, 'pred_col': 'Average ELA Proficiency', 'pred_coef': 0.4551896142499369}]

# %%
def get_single_regressor_model(col_name, pred_train, response_train, pred_test, response_test, response_var, categorical_bool):
    model_rows = []
    
    col_list = pred_train.columns.values
    
    if categorical_bool == True:
        col_vars = [var for var in col_list if "{}_".format(col_name) in var]
    else:
        col_vars = [col_name]
    x_train_df = pred_train[col_vars]
    x_test_df = pred_test[col_vars]
    x_model = linear_model.LinearRegression()
    x_results = x_model.fit(x_train_df, response_train[response_var])

    y_predicted_test = x_results.predict(x_test_df)
    med_absolute_error = metrics.median_absolute_error(response_test[response_var], y_predicted_test)
    r2 = metrics.r2_score(response_test[response_var],y_predicted_test)
    adj_r2 = adj_r2_score(x_results, response_test[response_var],y_predicted_test)

    coef_dict = {}
    model_rows = []
    for idx, col in enumerate(x_train_df.columns.values):
        coef_dict[col] = x_results.coef_[idx]
        model_row = {}
        model_row['model'] = col_name
        pred_coef = x_results.coef_[idx]
        model_row['model_r2'] = r2
        model_row['model_adj_r2'] = adj_r2
        model_row['median_absolute_error'] = med_absolute_error
        model_row['pred_col'] = col if categorical_bool == True else None
        model_row['pred_coef'] = pred_coef
        model_row['categorical'] = categorical_bool
        model_rows.append(model_row)

    return model_rows

# %% [raw]
# pred_train.head()

# %%
single_regression_df = pd.DataFrame()
 
for col in pred_train.columns.values:
    if col in invalid_preds:
        continue
    else: 
        categorical = True if pred_train[col].dtype == "object" else False
        pred_rows = get_single_regressor_model(col, pred_train, response_train, pred_test, response_test, response_var, categorical)
        single_regression_df = single_regression_df.append(pred_rows, ignore_index=True)
#     elif pred_train[col].dtype == "float":
#         continue
#         #pred_rows = get_numerical_model(col, pred_train, response_train)
#         #num_pred_df = num_pred_df.append(pred_rows, ignore_index=True)
single_regression_df_cols = ["model", "categorical", "model_r2", "model_adj_r2", "median_absolute_error", "pred_col", "pred_coef"]
single_regression_df[single_regression_df_cols]
# Out:
#                                                  model  categorical  model_r2  \
# 0                              Average ELA Proficiency        False  0.492734
# 1                             Average Math Proficiency        False  0.469334
# 2                             Collaborative Teachers %        False  0.008211
# 3                        Collaborative Teachers Rating         True  0.100027
# 4                        Collaborative Teachers Rating         True  0.100027
# 5                        Collaborative Teachers Rating         True  0.100027
# 6                        Collaborative Teachers Rating         True  0.100027
# 7                                    Community School?         True  0.030821
# 8                                             District        False  0.005003
# 9                                  Economic Need Index        False  0.329707
# 10                       Effective School Leadership %        False -0.000580
# 11                  Effective School Leadership Rating         True  0.011760
# 12                  Effective School Leadership Rating         True  0.011760
# 13                  Effective School Leadership Rating         True  0.011760
# 14                  Effective School Leadership Rating         True  0.011760
# 15                                       Percent Asian        False  0.204357
# 16                                       Percent Black        False -0.013265
# 17                            Percent Black / Hispanic        False  0.263372
# 18                                         Percent ELL        False  0.079345
# 19                                    Percent Hispanic        False  0.137247
# 20                                       Percent White        False  0.131556
# 21              Percent of Students Chronically Absent        False  0.069925
# 22                              Rigorous Instruction %        False  0.035900
# 23                         Rigorous Instruction Rating         True  0.113558
# 24                         Rigorous Instruction Rating         True  0.113558
# 25                         Rigorous Instruction Rating         True  0.113558
# 26                         Rigorous Instruction Rating         True  0.113558
# 27                      Strong Family-Community Ties %        False -0.024244
# 28                 Strong Family-Community Ties Rating         True  0.017859
# 29                 Strong Family-Community Ties Rating         True  0.017859
# ..                                                 ...          ...       ...
# 111  Strong Family-Community Ties Rating_Not Meetin...        False -0.001152
# 112            Strong Family-Community Ties Rating_nan        False -0.002332
# 113                    Trust Rating_Approaching Target        False -0.009451
# 114                      Trust Rating_Exceeding Target        False -0.013451
# 115                    Trust Rating_Not Meeting Target        False -0.013233
# 116                                   Trust Rating_nan        False -0.002332
# 117      Student Achievement Rating_Approaching Target        False  0.022153
# 118        Student Achievement Rating_Exceeding Target        False  0.045872
# 119      Student Achievement Rating_Not Meeting Target        False -0.012256
# 120                     Student Achievement Rating_nan        False -0.009779
# 121                                      borough_bronx        False  0.012337
# 122                                  borough_manhattan        False -0.027033
# 123                                     borough_queens        False -0.003008
# 124                              borough_staten_island        False -0.014932
# 125                              discretionary_funding        False -0.009490
# 126                                            Major N        False  0.066972
# 127                                              Oth N        False  0.055424
# 128                                           NoCrim N        False  0.086891
# 129                                             Prop N        False  0.051903
# 130                                              Vio N        False  0.044339
# 131                                       AvgOfMajor N        False -0.014285
# 132                                         AvgOfOth N        False -0.014062
# 133                                      AvgOfNoCrim N        False -0.011626
# 134                                        AvgOfProp N        False -0.015527
# 135                                         AvgOfVio N        False -0.014014
# 136                                 Major N_proportion        False  0.075657
# 137                                   Oth N_proportion        False  0.042945
# 138                                NoCrim N_proportion        False  0.083742
# 139                                  Prop N_proportion        False  0.028690
# 140                                   Vio N_proportion        False  0.061574
#
#      model_adj_r2  median_absolute_error  \
# 0        0.488164               0.102716
# 1        0.464553               0.091530
# 2       -0.000724               0.157957
# 3        0.066694               0.134547
# 4        0.066694               0.134547
# 5        0.066694               0.134547
# 6        0.066694               0.134547
# 7        0.022090               0.154208
# 8       -0.003961               0.150164
# 9        0.323668               0.109868
# 10      -0.009594               0.159520
# 11      -0.024841               0.153343
# 12      -0.024841               0.153343
# 13      -0.024841               0.153343
# 14      -0.024841               0.153343
# 15       0.197190               0.111687
# 16      -0.022393               0.145489
# 17       0.256736               0.109889
# 18       0.071051               0.156959
# 19       0.129475               0.126317
# 20       0.123733               0.126754
# 21       0.061546               0.122822
# 22       0.027214               0.154681
# 23       0.080727               0.136592
# 24       0.080727               0.136592
# 25       0.080727               0.136592
# 26       0.080727               0.136592
# 27      -0.033472               0.148817
# 28      -0.018517               0.140264
# 29      -0.018517               0.140264
# ..            ...                    ...
# 111     -0.010171               0.144225
# 112     -0.011362               0.143943
# 113     -0.018545               0.154940
# 114     -0.022581               0.150644
# 115     -0.022361               0.146964
# 116     -0.011362               0.143943
# 117      0.013343               0.146283
# 118      0.037276               0.125172
# 119     -0.021375               0.146289
# 120     -0.018876               0.142581
# 121      0.003439               0.151359
# 122     -0.036285               0.149483
# 123     -0.012044               0.146025
# 124     -0.024076               0.146172
# 125     -0.018585               0.141023
# 126      0.058567               0.143979
# 127      0.046914               0.144253
# 128      0.078664               0.147342
# 129      0.043362               0.133881
# 130      0.035730               0.155142
# 131     -0.023423               0.145904
# 132     -0.023198               0.147353
# 133     -0.020739               0.146199
# 134     -0.024676               0.147600
# 135     -0.023150               0.147781
# 136      0.067330               0.149828
# 137      0.034323               0.157169
# 138      0.075487               0.157412
# 139      0.019939               0.152897
# 140      0.053119               0.155458
#
#                                               pred_col     pred_coef
# 0                                                 None  4.551896e-01
# 1                                                 None  3.729197e-01
# 2                                                 None  4.854617e-01
# 3     Collaborative Teachers Rating_Approaching Target -5.743640e-02
# 4       Collaborative Teachers Rating_Exceeding Target  1.126679e-01
# 5     Collaborative Teachers Rating_Not Meeting Target -2.157462e-01
# 6                    Collaborative Teachers Rating_nan  2.380709e-01
# 7                                Community School?_Yes -2.129730e-01
# 8                                                 None  8.922581e-04
# 9                                                 None -6.588237e-01
# 10                                                None  3.857124e-01
# 11   Effective School Leadership Rating_Approaching... -7.260912e-02
# 12   Effective School Leadership Rating_Exceeding T...  4.614395e-02
# 13   Effective School Leadership Rating_Not Meeting... -7.977825e-02
# 14              Effective School Leadership Rating_nan  1.177954e-01
# 15                                                None  7.410586e-01
# 16                                                None -1.602161e-01
# 17                                                None -4.626095e-01
# 18                                                None -6.277992e-01
# 19                                                None -3.039353e-01
# 20                                                None  4.823748e-01
# 21                                                None -9.516386e-01
# 22                                                None  7.337244e-01
# 23      Rigorous Instruction Rating_Approaching Target -1.118005e-01
# 24        Rigorous Instruction Rating_Exceeding Target  1.257263e-01
# 25      Rigorous Instruction Rating_Not Meeting Target -1.558271e-01
# 26                     Rigorous Instruction Rating_nan  2.071976e-01
# 27                                                None  2.454385e-01
# 28   Strong Family-Community Ties Rating_Approachin...  2.267344e-02
# 29   Strong Family-Community Ties Rating_Exceeding ...  8.116264e-02
# ..                                                 ...           ...
# 111                                               None  3.335430e-02
# 112                                               None  1.069677e-01
# 113                                               None -1.055442e-01
# 114                                               None  4.325626e-02
# 115                                               None -6.317897e-02
# 116                                               None  1.069677e-01
# 117                                               None -1.474754e-01
# 118                                               None  1.808752e-01
# 119                                               None -1.509559e-01
# 120                                               None  1.467018e-01
# 121                                               None -7.302468e-02
# 122                                               None  2.108309e-02
# 123                                               None  5.340775e-02
# 124                                               None -3.077230e-02
# 125                                               None  1.344060e-08
# 126                                               None -2.556989e-02
# 127                                               None -7.592503e-03
# 128                                               None -4.408266e-03
# 129                                               None -9.773849e-03
# 130                                               None -1.324768e-02
# 131                                               None  4.575590e-03
# 132                                               None  1.581160e-03
# 133                                               None  1.376064e-04
# 134                                               None  3.029064e-03
# 135                                               None  3.147961e-03
# 136                                               None -4.007858e-02
# 137                                               None -5.403944e-02
# 138                                               None -6.472227e-02
# 139                                               None -4.795894e-02
# 140                                               None -4.108991e-02
#
# [141 rows x 7 columns]

# %%
cat_pred_df = cat_pred_df[cat_pred_df_cols]

# %%
cat_pred_df.to_csv("/Users/greg.bolla/Desktop/git-projects/kaggle-passnyc/models/categorical_single_regression.csv".format(data_dir), index=False)
num_pred_df.to_csv("/Users/greg.bolla/Desktop/git-projects/kaggle-passnyc/models/numerical_single_regression.csv".format(data_dir), index=False)

# %%
def get_numerical_model(col_name, pred_train_df, response_train_df):
    model_rows = []
    
    x_train_df = pred_train_df[col_name]
    x_train_df = sm.add_constant(x_train_df)

    x_model = sm.OLS(response_train_df, x_train_df, missing='drop')
    x_results = x_model.fit()
    
    num_obs = x_results.nobs
    r2 = x_results.rsquared
    adj_r2 = x_results.rsquared_adj
    f_stat = x_results.fvalue
    f_stat_pval = x_results.f_pvalue
    aic = x_results.aic
    bic = x_results.bic
    for i, pred_pval in enumerate(x_results.pvalues):
        if np.isnan(pred_pval):
            print(x_results.summary())
            continue
        model_row = {}
        model_row['model'] = col_name
        if len(x_results.pvalues[x_results.pvalues == pred_pval]) > 1:
            print(x_results.pvalues[x_results.pvalues == pred_pval])
            raise ValueError('multiple preds have same pval')
        pred_col = x_results.pvalues[x_results.pvalues == pred_pval].index[0]
        pred_coef = x_results.params[pred_col]
        
        
        model_row['model_r2'] = r2
        model_row['model_adj_r2'] = adj_r2
        model_row['model_f_stat'] = f_stat
        model_row['model_f_stat_pval'] = f_stat_pval
        model_row['model_aic'] = aic
        model_row['model_bic'] = bic
        model_row['pred_col'] = pred_col
        model_row['pred_coef'] = pred_coef
        model_row['pred_col_pval'] = pred_pval
        if pred_col != 'const':
            model_row['pred_num_miss'] = pred_train_df[pred_col].isnull().sum()
        model_rows.append(model_row)

    return model_rows

# %%
def get_dist_from_specialized_schools(row):
   
    row_long_lat = (float(row['Latitude']), float(row['Longitude']))

    specialized_school_long_lat = {
        "bronx_hs_of_science" : (40.87833, -73.89083),
        "brooklyn_latin_school" : (40.705, -73.9388889),
        "brooklyn_tech_hs" : (40.6888889, -73.9766667),
        "hs_for_math_sci_eng" : (40.8215, -73.9490),
        "hs_of_amer_studies" : (40.8749, -73.8952),
        "queens_hs_for_sci": (40.699, -73.797),
        "staten_island_tech" : (40.5676, -74.1181),
        "stuyvesant_hs" : (40.7178801, -74.0137509)
    }
    
    #dist_df = pd.DataFrame()
    row = {}
    for specialized_school, specialized_long_lat in specialized_school_long_lat.items():
        row["dist_to_{}".format(specialized_school)] = geopy.distance.vincenty(row_long_lat, specialized_long_lat).miles       
    row["min_dist_to_specialized_school"] = row[min(row, key=row.get)]
    return pd.Series(row)

# %%
dist_df = modeling_df.apply(get_dist_from_specialized_schools, axis=1)

# %%
dist_df.head()
# Out:
#    dist_to_bronx_hs_of_science  dist_to_brooklyn_latin_school  \
# 0                    18.275778                       6.328220
# 1                    21.354160                       9.159982
# 2                     6.562026                       6.708981
# 3                    15.051826                       3.301437
# 4                    11.043313                       4.222236
#
#    dist_to_brooklyn_tech_hs  dist_to_hs_for_math_sci_eng  \
# 0                  4.450203                    13.670928
# 1                  7.650721                    16.910698
# 2                  7.736581                     1.618959
# 3                  1.226399                    10.471718
# 4                  3.942374                     6.123651
#
#    dist_to_hs_of_amer_studies  dist_to_queens_hs_for_sci  \
# 0                   17.978016                  11.933558
# 1                   21.068363                  13.207266
# 2                    6.236976                  11.169889
# 3                   14.753907                  10.027592
# 4                   10.721510                  11.193139
#
#    dist_to_staten_island_tech  dist_to_stuyvesant_hs  \
# 0                    7.300248               6.233516
# 1                    6.658060               9.671763
# 2                   18.023136               6.297388
# 3                   10.065957               3.504831
# 4                   13.518514               1.805418
#
#    min_dist_to_specialized_school
# 0                        4.450203
# 1                        6.658060
# 2                        1.618959
# 3                        1.226399
# 4                        1.805418

# %%
example_df = pd.concat([modeling_df, dist_df], axis=1)

# %%
example_df.head()
# Out:
#                                          school_name     dbn  num_testtakers  \
# 0              THE CHRISTA MCAULIFFE SCHOOL\I.S. 187  20K187           251.0
# 1      MARK TWAIN I.S. 239 FOR THE GIFTED & TALENTED  21K239           336.0
# 2                    J.H.S. 054 BOOKER T. WASHINGTON  03M054           257.0
# 3                          M.S. 51 WILLIAM ALEXANDER  15K051           280.0
# 4  NEW YORK CITY LAB MIDDLE SCHOOL FOR COLLABORAT...  02M312           163.0
#
#    num_offered  pct_8th_graders_offered  pct_black_hispanic      SED Code  \
# 0        205.0                     0.75                0.08  3.320000e+11
# 1        196.0                     0.46                0.13  3.321000e+11
# 2        150.0                     0.53                0.23  3.103000e+11
# 3        122.0                     0.33                0.28  3.315000e+11
# 4        113.0                     0.62                0.08  3.102000e+11
#
#    District   Latitude  Longitude               ...                \
# 0      20.0  40.627847 -74.004003               ...
# 1      21.0  40.578660 -73.992391               ...
# 2       3.0  40.800512 -73.962802               ...
# 3      15.0  40.672180 -73.984625               ...
# 4       2.0  40.742571 -74.002371               ...
#
#   Student Achievement Rating_nan dist_to_bronx_hs_of_science  \
# 0                            0.0                   18.275778
# 1                            0.0                   21.354160
# 2                            0.0                    6.562026
# 3                            0.0                   15.051826
# 4                            0.0                   11.043313
#
#    dist_to_brooklyn_latin_school dist_to_brooklyn_tech_hs  \
# 0                       6.328220                 4.450203
# 1                       9.159982                 7.650721
# 2                       6.708981                 7.736581
# 3                       3.301437                 1.226399
# 4                       4.222236                 3.942374
#
#   dist_to_hs_for_math_sci_eng  dist_to_hs_of_amer_studies  \
# 0                   13.670928                   17.978016
# 1                   16.910698                   21.068363
# 2                    1.618959                    6.236976
# 3                   10.471718                   14.753907
# 4                    6.123651                   10.721510
#
#   dist_to_queens_hs_for_sci  dist_to_staten_island_tech  \
# 0                 11.933558                    7.300248
# 1                 13.207266                    6.658060
# 2                 11.169889                   18.023136
# 3                 10.027592                   10.065957
# 4                 11.193139                   13.518514
#
#    dist_to_stuyvesant_hs  min_dist_to_specialized_school
# 0               6.233516                        4.450203
# 1               9.671763                        6.658060
# 2               6.297388                        1.618959
# 3               3.504831                        1.226399
# 4               1.805418                        1.805418
#
# [5 rows x 246 columns]

# %%
preds = [
"Average ELA Proficiency", 
"Average Math Proficiency",
"sa_attendance_90plus_2017" , 
"min_dist_to_specialized_school",
"Student Achievement Rating_Approaching Target",
"Student Achievement Rating_Exceeding Target",
"Student Achievement Rating_Not Meeting Target",
"Student Achievement Rating_nan",
"Strong Family-Community Ties Rating_Approaching Target",
"Strong Family-Community Ties Rating_Exceeding Target",
"Strong Family-Community Ties Rating_Not Meeting Target",
"Strong Family-Community Ties Rating_nan",
"pct_8th_graders_w_hs_credit_2017",
"borough_bronx",
"borough_manhattan",
"borough_queens",
"borough_staten_island"
]

cols_to_standardize = [
    "Average ELA Proficiency", 
    "Average Math Proficiency",
    "sa_attendance_90plus_2017",
    "min_dist_to_specialized_school",
    "pct_8th_graders_w_hs_credit_2017"
]
#x_train = pred_train[preds]

#len(x_train.dropna())
#mul_lr = linear_model.LogisticRegression(multi_class='multinomial', solver='newton-cg').fit(x_train, response_train)
 

#sm_x_train = sm.add_constant(sm_x_train)

# %%
subsetted_modeling_df = modeling_df[]

subsetted_modeling_df = subsetted_modeling_df.dropna()
subsetted_pred_df = subsetted_modeling_df[preds]
subsetted_response_df = subsetted_modeling_df["perc_testtakers_quartile"]
subsetted_pred_train, subsetted_pred_test, subsetted_response_train, subsetted_response_test = train_test_split(subsetted_pred_df, subsetted_response_df, test_size=0.2, random_state=223)


#multinom_response_df = modeling_df["perc_testtakers_quartile"]

# %%
mul_lr = linear_model.LogisticRegression(multi_class='multinomial', solver='newton-cg').fit(subsetted_pred_train, subsetted_response_train)

# %%
print("Logistic regression Train Accuracy :: ", metrics.accuracy_score(subsetted_response_train, mul_lr.predict(subsetted_pred_train)))
print("Logistic regression Test Accuracy :: ", metrics.accuracy_score(subsetted_response_test, mul_lr.predict(subsetted_pred_test)))
# Out:
# Logistic regression Train Accuracy ::  0.4964871194379391
# Logistic regression Test Accuracy ::  0.48598130841121495

# %%
print(mul_lr.predict(subsetted_pred_train))
# Out:
# [4. 4. 1. 2. 1. 2. 1. 1. 4. 1. 4. 1. 4. 1. 2. 1. 2. 4. 1. 1. 4. 4. 1. 1.
#  1. 3. 2. 1. 4. 2. 3. 4. 3. 1. 4. 1. 4. 3. 1. 2. 1. 1. 3. 1. 3. 1. 1. 4.
#  3. 4. 1. 1. 2. 1. 4. 2. 1. 4. 3. 3. 3. 2. 3. 1. 1. 4. 1. 3. 4. 3. 3. 1.
#  3. 1. 1. 2. 4. 4. 4. 3. 4. 1. 4. 4. 1. 4. 3. 4. 1. 4. 4. 2. 2. 1. 4. 4.
#  2. 3. 4. 3. 1. 1. 2. 2. 4. 4. 3. 1. 1. 1. 1. 3. 2. 2. 2. 2. 2. 2. 3. 2.
#  2. 4. 2. 1. 2. 4. 2. 4. 2. 1. 1. 1. 1. 4. 4. 3. 1. 4. 1. 1. 4. 2. 4. 1.
#  4. 4. 3. 1. 4. 1. 2. 2. 2. 4. 3. 1. 4. 4. 2. 3. 1. 3. 4. 1. 3. 1. 1. 4.
#  4. 2. 2. 2. 4. 1. 4. 1. 4. 1. 1. 2. 2. 2. 2. 4. 2. 3. 4. 2. 3. 1. 3. 4.
#  1. 4. 1. 3. 2. 1. 3. 3. 2. 1. 4. 1. 4. 1. 4. 1. 4. 4. 2. 1. 3. 3. 4. 2.
#  4. 1. 4. 2. 1. 2. 1. 3. 2. 1. 1. 4. 1. 2. 1. 3. 2. 3. 3. 1. 4. 2. 4. 4.
#  2. 1. 1. 4. 3. 4. 2. 1. 1. 4. 3. 1. 2. 2. 4. 4. 3. 1. 1. 2. 2. 4. 2. 1.
#  4. 1. 4. 1. 4. 1. 1. 4. 2. 3. 1. 1. 4. 1. 2. 3. 4. 3. 4. 4. 1. 2. 1. 4.
#  4. 2. 4. 2. 2. 3. 4. 1. 2. 1. 4. 2. 1. 4. 2. 2. 1. 3. 4. 2. 2. 4. 2. 2.
#  2. 1. 1. 1. 2. 3. 1. 1. 4. 4. 1. 1. 3. 2. 4. 1. 2. 1. 1. 1. 4. 1. 2. 4.
#  2. 1. 4. 3. 1. 1. 4. 1. 4. 4. 3. 3. 3. 1. 3. 3. 2. 4. 3. 1. 3. 2. 1. 1.
#  2. 1. 3. 2. 2. 2. 4. 2. 1. 1. 4. 4. 1. 4. 4. 4. 3. 1. 2. 1. 3. 4. 4. 1.
#  1. 3. 3. 3. 3. 2. 1. 4. 4. 4. 4. 1. 4. 4. 1. 4. 1. 3. 2. 1. 3. 2. 1. 3.
#  1. 1. 1. 2. 2. 3. 1. 3. 4. 2. 4. 4. 4. 4. 2. 3. 3. 4. 2.]

# %%
print(subsetted_response_train)
# Out:
# 6      4.0
# 153    1.0
# 345    2.0
# 160    1.0
# 166    1.0
# 451    3.0
# 156    1.0
# 349    4.0
# 322    4.0
# 326    2.0
# 39     3.0
# 203    1.0
# 64     4.0
# 492    4.0
# 56     3.0
# 317    2.0
# 301    2.0
# 342    2.0
# 475    3.0
# 249    1.0
# 66     3.0
# 285    3.0
# 292    1.0
# 455    2.0
# 254    1.0
# 60     3.0
# 294    2.0
# 307    1.0
# 162    3.0
# 35     4.0
#       ...
# 27     4.0
# 199    2.0
# 515    4.0
# 351    3.0
# 104    3.0
# 187    1.0
# 149    1.0
# 450    3.0
# 338    2.0
# 315    1.0
# 434    4.0
# 172    1.0
# 214    1.0
# 232    2.0
# 481    3.0
# 403    2.0
# 116    1.0
# 272    1.0
# 98     4.0
# 14     4.0
# 408    4.0
# 76     4.0
# 206    3.0
# 284    4.0
# 159    1.0
# 454    2.0
# 177    1.0
# 112    3.0
# 17     4.0
# 483    1.0
# Name: perc_testtakers_quartile, Length: 427, dtype: float64

# %%
modeling_df.City.value_counts()
# Out:
# BROOKLYN               185
# BRONX                  137
# NEW YORK               115
# STATEN ISLAND           17
# JAMAICA                 14
# FLUSHING                13
# LONG ISLAND CITY        10
# FAR ROCKAWAY             6
# SPRINGFIELD GARDENS      5
# ROCKAWAY PARK            4
# ELMHURST                 4
# MIDDLE VILLAGE           4
# ASTORIA                  4
# JACKSON HEIGHTS          3
# BAYSIDE                  3
# OZONE PARK               3
# HOWARD BEACH             3
# QUEENS VILLAGE           2
# ROSEDALE                 2
# GLENDALE                 2
# RIDGEWOOD                2
# REGO PARK                2
# SOUTH OZONE PARK         2
# EAST ELMHURST            2
# ARVERNE                  2
# SAINT ALBANS             2
# BELLEROSE                2
# FOREST HILLS             1
# ROCKAWAY BEACH           1
# MASPETH                  1
# ROOSEVELT ISLAND         1
# CORONA                   1
# CAMBRIA HEIGHTS          1
# FLORAL PARK              1
# HOLLIS                   1
# WHITESTONE               1
# LITTLE NECK              1
# BROAD CHANNEL            1
# WOODSIDE                 1
# Name: City, dtype: int64

# %%
col = "Average ELA Proficiency"
pred_train[col].isnull().sum()
# Out:
# 0
